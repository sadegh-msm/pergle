# %%
import datetime
import json
import re
import math
import pickle
from hazm import *

data_content = []
data_url = []
data_title = []
masked_id = {}

normalizer = Normalizer()
stemmer = Stemmer()
lemmatizer = Lemmatizer()

stop_words = set(stopwords_list())
# print("stop words: ", stop_words)

def load_data():
    _file = open('index', 'rb')
    data = pickle.load(_file)

    return data

def store_data(obj):
    _file = open('index', 'ab')
    pickle.dump(obj, _file)

def preProcess(data):
    json_keys = list(data.keys())

    for i in range(len(data)):
        masked_id[i] = json_keys[i]

    # Extracting data to arrays
    for i in json_keys:
        index = str(i)
        data_content.append(data[index]["content"])
        data_url.append(data[index]["url"])
        data_title.append(data[index]["title"])

    # Initializing variables and objects
    # stop_words = set(stopwords_list())
    # print("stop words: ", stop_words)

    punctuations = [')', '(', '>', '<', "؛", "،", '{', '}', "؟", ':', "–", '»', '"', '«', '[', ']', '"', '+', '=', '?',
                    '/', '//', '\\', '|', '!', '%', '&', '*', '$', '#', '؟', '*', '.', '_', '\u200c']
    punctuations_set = set(punctuations)

    data_tokens = []

    # Processing each document
    for content in data_content:
        # Normalizing and tokenizing the content
        content = normalizer.normalize(content)
        tokens = word_tokenize(content)

        # Removing stop words and punctuations
        tokens = [token for token in tokens if token not in stop_words and token not in punctuations_set]
        # tokens = [token for token in tokens if token not in punctuations_set]

        # Lemmatizing and stemming each token
        tokens = [lemmatizer.lemmatize(token) for token in tokens]
        # tokens = [stemmer.stem(token) for token in tokens]

        data_tokens.append(tokens)

    # temp = []
    # for data_token in data_tokens:
    #     temp.append(data_token)
    #
    # dic = set(temp)
    # print("length of dic: ", dic)

    return data_tokens


def update_postings(postings, docId, term_position):
    if docId not in postings:
        postings[docId] = {'positions': [], 'freq_in_doc': 0}
    postings[docId]['positions'].append(term_position)
    postings[docId]['freq_in_doc'] += 1


def positional_indexing(ppd):
    p_inv_index = {}
    for docId, doc in enumerate(ppd):
        for pos, term in enumerate(doc):
            if term in p_inv_index:
                update_postings(p_inv_index[term]['postings'], docId, pos)
                p_inv_index[term]['total_freq'] += 1
            else:
                p_inv_index[term] = {'postings': {docId: {'positions': [pos], 'freq_in_doc': 1}}, 'total_freq': 1}
    return p_inv_index


def get_terms_freq(positionalIndex):
    freq = {}
    for term in positionalIndex:
        freq[term] = positionalIndex[term]['total_freq']
    return freq


def query_service(and_terms, not_terms, phrase_term, pi):
    normalizer = Normalizer()
    stemmer = Stemmer()
    lemmatizer = Lemmatizer()

    for i in range(len(and_terms)):
        and_terms[i] = normalizer.normalize(and_terms[i])
        and_terms[i] = lemmatizer.lemmatize(and_terms[i])
        and_terms[i] = stemmer.stem(and_terms[i])

    for i in range(len(not_terms)):
        not_terms[i] = normalizer.normalize(not_terms[i])
        not_terms[i] = lemmatizer.lemmatize(not_terms[i])
        not_terms[i] = stemmer.stem(not_terms[i])

    for i in range(len(phrase_term)):
        for j in range(len(phrase_term[i])):
            phrase_term[i][j] = normalizer.normalize(phrase_term[i][j])
            phrase_term[i][j] = lemmatizer.lemmatize(phrase_term[i][j])
            phrase_term[i][j] = stemmer.stem(phrase_term[i][j])

    doc_ids = set(range(len(preprocessed_docs)))

    for term in not_terms:
        if term in pi:
            term_postings = set(pi[term]['postings'].keys())
            doc_ids.difference_update(term_postings)

    doc_freqs = {}
    for term in and_terms:
        if term in pi:
            term_postings = pi[term]['postings']
            for doc_id, doc_postings in term_postings.items():
                if doc_id in doc_ids and doc_postings['freq_in_doc'] > 0:
                    if doc_id not in doc_freqs:
                        doc_freqs[doc_id] = 0
                    doc_freqs[doc_id] += doc_postings['freq_in_doc']
    phrase_dict = {}
    if len(phrase_term) > 0:
        phrase_str = ' '.join(phrase_term[0])
        phrase_dict[phrase_str] = []

    for phrase in phrase_dict:
        phrase_list = phrase.split(' ')
        dic = {}
        for i in range(len(phrase_list)):
            if phrase_list[i] in pi:
                term_postings = pi[phrase_list[i]]['postings']
                for doc_id, doc_postings in term_postings.items():
                    if doc_id not in dic:
                        dic[doc_id] = []
                    dic[doc_id].append(doc_postings['positions'])
        phrase_dict[phrase] = dic

    for phrase in phrase_dict:
        for doc_id in phrase_dict[phrase]:
            pos_lists = phrase_dict[phrase][doc_id]
            idx = 0
            while idx < len(pos_lists) - 1:
                if pos_lists[idx + 1][0] - pos_lists[idx][-1] == 1:
                    idx += 1
                else:
                    break
            if idx == len(pos_lists) - 1:
                if doc_id in doc_freqs:
                    doc_freqs[doc_id] += 1
                else:
                    doc_freqs[doc_id] = 1

    ranked_docs = sorted(doc_freqs.items(), key=lambda x: x[1], reverse=True)

    return ranked_docs


def executing_query(data):
    # Example usage
    query = 'باید'

    phrase_query = get_phrase(query)
    not_query = not_terms(query)
    flat_phrases = [item for sublist in phrase_query for item in sublist]
    not_words = not_terms(query)
    query = query.replace('"', '')
    query = query.replace('!', '')
    splitted_query = query.split()
    looking_words = []
    for x in splitted_query:
        if x not in not_words and x not in flat_phrases:
            looking_words.append(x)

    a = datetime.datetime.now()
    result_docs = query_service(looking_words, not_query, phrase_query, positional_index)
    b = datetime.datetime.now()
    print("{:<5} result in {} ms\n".format(len(result_docs), 1000 * (b - a).total_seconds()))

    if len(result_docs) > 5:
        for i in range(5):
            num = str(result_docs[i])
            num = num.split(' ')
            right = num[1].split(')')
            score = right[0]
            left = num[0].split(',')
            left = left[0].split('(')
            document_id = left[1]

            print("document id: ", document_id, end='   ')
            print("score: " + score, end='  ')
            print(data[document_id]['title'])
            print(data[document_id]['url'], end='')
            print(data[document_id]['content'])
            print('-----------------------------------------------')


def get_phrase(query):
    res = []
    quoted = re.compile('"[^"]*"')
    for value in quoted.findall(query):
        value = value.replace('"', '').strip().split()
        res.append(value)
    return res


def not_terms(query):
    splitted_query = query.split()
    indices = [i for i in range(len(splitted_query)) if splitted_query[i] == '!']
    result = [splitted_query[i + 1] for i in indices]
    return result

# %%
with open("../IR_data_news_5k.json") as file:
    json_data = json.load(file)

preprocessed_docs = preProcess(json_data)

positional_index = positional_indexing(preprocessed_docs)

# sw = {}
# for term in stop_words:
#     if term in positional_index:
#         sw[term] = len(positional_index[term]['postings'])
#
# ssw = sorted(sw.items(), key=lambda x: x[1], reverse=True)
# print(ssw)

# print("length postings list: ",len(positional_index))

# executing_query(positional_index)


store_data(positional_index)

# %%
length_for_doc = {}

# all_term_freq = 0
# for term in positional_index:
#     for doc in positional_index[term]['postings']:
#         all_term_freq += positional_index[term]['postings'][doc]['freq_in_doc']

tokennn = []
for doc in data_content:
    tokennn = word_tokenize(doc)

tokenn = {}
for i in range(len(tokennn)):
    if tokennn[i] in tokenn:
        tokenn[tokennn[i]] += 1
    else:
        tokenn[tokennn[i]] = 1

summ = 0
for i in tokenn:
    summ += tokenn[i]

avg = summ/len(tokenn)

def calculate_documents_tf_idf():
    for term in positional_index:
        for doc in positional_index[term]['postings']:
            term_frequency = positional_index[term]['postings'][doc]['freq_in_doc']
            N = len(data_content)
            df = len(positional_index[term]['postings'])
            tf_idf = (1 + math.log2(term_frequency) / 1 + math.log2(avg)) * max(float(0), math.log2((N-df)/df))
            positional_index[term]['postings'][doc]['tf_idf'] = tf_idf
            if doc in length_for_doc:
                length_for_doc[doc] += tf_idf ** 2
            else:
                length_for_doc[doc] = tf_idf ** 2
    for doc_id in length_for_doc:
        length_for_doc[doc_id] = math.sqrt(length_for_doc[doc_id])

    # temp = {}
    # for term in positional_index:
    #     temp[term] = (math.log2(len(data_content) / positional_index[term]['total_freq']))
    #
    # sortedd = sorted(temp.items(), key=lambda item: item[1], reverse=True)


    # print(sortedd)

# %%
def cosine_score(query, k):
    query_tf = {}
    query_length = 0
    doc_cosine_score_dic = {}

    # Calculate term frequencies for query
    for term in query.split(" "):
        word = lemmatizer.lemmatize(normalizer.normalize(term))
        query_tf[word] = query_tf.get(word, 0) + 1

    # Calculate query length and apply logarithmic scaling to term frequencies
    for term, tf in query_tf.items():
        query_tf[term] = 1 + math.log2(tf)
        query_length += query_tf[term] ** 2

    # Calculate cosine scores
    for term in query_tf.keys():
        if term in positional_index:
            for doc_id in positional_index[term]['postings']:
                tf_idf = positional_index[term]['postings'][doc_id]['tf_idf']
                doc_cosine_score_dic[doc_id] = doc_cosine_score_dic.get(doc_id, 0) + query_tf[term] * tf_idf

    # Normalize cosine scores
    for doc in doc_cosine_score_dic:
        doc_cosine_score_dic[doc] /= (length_for_doc[doc] * query_length)

    # Sort documents by score
    sorted_doc_cosine_score = sorted(doc_cosine_score_dic.items(), key=lambda item: item[1], reverse=True)
    return sorted_doc_cosine_score[:k]

# %%
def jacquard_score(query, k):
    query_set = set(lemmatizer.lemmatize(token.lower()) for token in word_tokenize(query) if token.isalpha())
    doc_jacquard_score_dic = {}
    for term in query_set:
        if term in positional_index:
            for doc_id in positional_index[term]['postings']:
                if doc_id not in doc_jacquard_score_dic:
                    doc_set = set(word_tokenize(data_content[doc_id]))
                    jacquard_score = len(query_set.intersection(doc_set)) / len(query_set.union(doc_set))
                    doc_jacquard_score_dic[doc_id] = jacquard_score
    sorted_doc_jacquard_score = sorted(doc_jacquard_score_dic.items(), key=lambda item: item[1], reverse=True)
    return sorted_doc_jacquard_score[:k]

# %%
def jacquard_score_with_champion_list(query, k, champion_lists):
    query_set = set(lemmatizer.lemmatize(token.lower()) for token in word_tokenize(query) if token.isalpha())
    doc_jacquard_score_dic = {}
    for term in query_set:
        if term in champion_lists:
            for doc_id in champion_lists[term]:
                if doc_id not in doc_jacquard_score_dic:
                    doc_set = set(word_tokenize(data_content[doc_id]))
                    jacquard_score = len(query_set.intersection(doc_set)) / len(query_set.union(doc_set))
                    doc_jacquard_score_dic[doc_id] = jacquard_score
    sorted_doc_jacquard_score = sorted(doc_jacquard_score_dic.items(), key=lambda item: item[1], reverse=True)
    return sorted_doc_jacquard_score[:k]

# %%
def create_champion_lists(k):
    r = 10 * k
    champion_lists = {}
    for term in positional_index:
        doc_tf_idf = {}
        for doc in positional_index[term]['postings']:
            doc_tf_idf[doc] = positional_index[term]['postings'][doc]['tf_idf'] / length_for_doc[doc]
        sorted_doc_tf_idf = sorted(doc_tf_idf.items(), key=lambda item: item[1], reverse=True)
        documents = [doc_score[0] for index, doc_score in enumerate(sorted_doc_tf_idf) if index <= r]
        champion_lists[term] = documents
    return champion_lists

# %%
calculate_documents_tf_idf()
query = 'تراکتور'
champ_list = create_champion_lists(4)
jacquard_score_with_champion_list(query,20,champ_list)
# Out:
# [(3630, 0.029411764705882353),
#  (3708, 0.023255813953488372),
#  (4545, 0.020833333333333332),
#  (195, 0.02),
#  (1757, 0.02),
#  (4600, 0.019230769230769232),
#  (4939, 0.01639344262295082),
#  (741, 0.016129032258064516),
#  (339, 0.015873015873015872),
#  (3027, 0.015625),
#  (2356, 0.014492753623188406),
#  (4227, 0.014285714285714285),
#  (1036, 0.014084507042253521),
#  (4446, 0.013888888888888888),
#  (3593, 0.0136986301369863),
#  (2885, 0.0136986301369863),
#  (2872, 0.0136986301369863),
#  (42, 0.013333333333333334),
#  (1181, 0.011904761904761904),
#  (3989, 0.011764705882352941)]

# %%
def cosine_score_with_champion_lists(query, k, champion_lists):
    query_tf = {}
    query_length = 0
    doc_cosine_score_dic = {}

    # Calculate term frequencies for query
    for term in query.split(" "):
        word = lemmatizer.lemmatize(normalizer.normalize(term))
        query_tf[word] = query_tf.get(word, 0) + 1

    # Calculate query length and apply logarithmic scaling to term frequencies
    for term, tf in query_tf.items():
        query_tf[term] = 1 + math.log2(tf)
        query_length += query_tf[term] ** 2

    # Calculate cosine scores
    for term in query_tf.keys():
        if term in champion_lists:
            for doc_id in champion_lists[term]:
                tf_idf = positional_index[term]['postings'][doc_id]['tf_idf']
                doc_cosine_score_dic[doc_id] = doc_cosine_score_dic.get(doc_id, 0) + query_tf[term] * tf_idf

    # Normalize cosine scores
    for doc in doc_cosine_score_dic:
        doc_cosine_score_dic[doc] /= (length_for_doc[doc] * query_length)

    # Sort documents by score
    sorted_doc_cosine_score = sorted(doc_cosine_score_dic.items(), key=lambda item: item[1], reverse=True)
    return sorted_doc_cosine_score[:k]

# %%
def compare_query(k, champions_list, query):
    cosine = cosine_score(query, 20)
    cosine_with_champ = cosine_score_with_champion_lists(query, 20, champions_list)
    jacquard = jacquard_score(query, 20)
    jacquard_with_champ = jacquard_score_with_champion_list(query, 20, champions_list)

    if len(cosine) > k:
        print("cosine: \n")
        for i in range(k):
            docID, score = cosine[i]
            print("found doc: ", masked_id[docID], "with score: ", score)
            print("title: ", data_title[docID])
            print("content: ", data_content[docID])
            print("--------------------------------------")

        print("cosine with champions list: \n")
        for i in range(k):
            docID, score = cosine_with_champ[i]
            print("found doc: ", masked_id[docID], "with score: ", score)
            print("title: ", data_title[docID])
            print("content: ", data_content[docID])
            print("--------------------------------------")

        print("jacquard: \n")
        for i in range(k):
            docID, score = jacquard[i]
            print("found doc: ", masked_id[docID], "with score: ", score)
            print("title: ", data_title[docID])
            print("content: ", data_content[docID])
            print("--------------------------------------")

        print("jacquard with champions list: \n")
        for i in range(k):
            docID, score = jacquard_with_champ[i]
            print("found doc: ", masked_id[docID], "with score: ", score)
            print("title: ", data_title[docID])
            print("content: ", data_content[docID])
    else:
        print("cosine: \n")
        for i in range(len(cosine)):
            docID, score = cosine[i]
            print("found doc: ", masked_id[docID], "with score: ", score)
            print("title: ", data_title[docID])
            print("content: ", data_content[docID])
            print("--------------------------------------")

        print("cosine with champions list: \n")
        for i in range(len(cosine_with_champ)):
            docID, score = cosine_with_champ[i]
            print("found doc: ", masked_id[docID], "with score: ", score)
            print("title: ", data_title[docID])
            print("content: ", data_content[docID])
            print("--------------------------------------")

        print("jacquard: \n")
        for i in range(len(jacquard)):
            docID, score = jacquard[i]
            print("found doc: ", masked_id[docID], "with score: ", score)
            print("title: ", data_title[docID])
            print("content: ", data_content[docID])
            print("--------------------------------------")

        print("jacquard with champions list: \n")
        for i in range(len(jacquard_with_champ)):
            docID, score = jacquard_with_champ[i]
            print("found doc: ", masked_id[docID], "with score: ", score)
            print("title: ", data_title[docID])
            print("content: ", data_content[docID])

# %%
if __name__ == '__main__':
    calculate_documents_tf_idf()
    query = 'نتیجه بازی تیم فوتبال'
    champ_list = create_champion_lists(5)
    compare_query(10, champ_list, query)
# Out:
# cosine:
#
# found doc:  3107 with score:  0.061451896428757063
# title:  واکنش AFC به پیروزی تیم ملی مقابل شاگردان مارویک/اماراتی ها با گل طارمی دبل شدند
# content:
# به گزارش خبرگزاری فارس، تیم ملی فوتبال کشورمان در مصاف با امارات با نتیجه یک بر صفر به پیروزی رسید. تک گل این بازی را مهدی طارمی در اواخر نیمه اول به ثمر رساند. صفحه رسمی کنفدراسیون فوتبال آسیا به پیروزی تیم ملی کشورمان واکنش نشان داد و نوشت: گل مهدی طارمی در نیمه اول برای دبل شدن امارات مقابل ایران کافی بود. اماراتی ها در دیدار رفت هم در کشورشان مقابل تیم ملی فوتبال کشورمان شکست خورده بودند. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:
انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  2568 with score:  0.047072041259259643
# title:  واکنش عجیب ارسلان مطهری به احتمال قهرمانی استقلال
# content:
# به گزارش خبرگزاری فارس، ارسلان مطهری پس از پیروزی استقلال مقابل پیکان در رقابت های جام حذفی فوتبال و اینکه در دیدارهای اخیر هر وقت زمین آمده گل زده است، اظهار داشت: لطف خدا شامل حال من می شود، زحمت همه بچه های تیم و انرژی مثبت هواداران باعث این اتفاق می شود. وی درباره این دیدار افزود: پیکان بازیکنان و مربی خیلی خوبی دارد و رفته رفته وقتی تعداد بازی ها بیشتر می شود، تیم ها فرم بهتری پیدا می کنند. وی درباره اینکه استقلال با توجه به پیروزی و تلاش در دو جبهه لیگ برتر و جام حذفی، قهرمانی این مسابقات را بدست می آورد؛ گفت: خدا را شکر. به گزارش فارس، استقلال در رقابت های فوتبال جام حذفی با نتیجه یک بر صفر از سد پیکان گذشت و به جمع 8 تیم برتر راه یافت. انتهای پیام/
#
#
#
# --------------------------------------
# cosine with champions list:
#
# found doc:  3107 with score:  0.05419123001048677
# title:  واکنش AFC به پیروزی تیم ملی مقابل شاگردان مارویک/اماراتی ها با گل طارمی دبل شدند
# content:
# به گزارش خبرگزاری فارس، تیم ملی فوتبال کشورمان در مصاف با امارات با نتیجه یک بر صفر به پیروزی رسید. تک گل این بازی را مهدی طارمی در اواخر نیمه اول به ثمر رساند. صفحه رسمی کنفدراسیون فوتبال آسیا به پیروزی تیم ملی کشورمان واکنش نشان داد و نوشت: گل مهدی طارمی در نیمه اول برای دبل شدن امارات مقابل ایران کافی بود. اماراتی ها در دیدار رفت هم در کشورشان مقابل تیم ملی فوتبال کشورمان شکست خورده بودند. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  6466 with score:  0.0445985384190001
# title:  شریفی: بارندگی کار را سخت کرده بود/ فاصله تیم‌ها در لیگ برتر زیاد نیست
# content:
# به گزارش خبرنگار ورزشی خبرگزاری فارس، محمد شریفی پس از پیروزی 4 بر صفر تیم فوتبال پرسپولیس مقابل ویستاتوربین در رقابت‌های جام حذفی اظهار داشت: خدا را شکر بازی خوبی بود. شرایط با توجه به وضعیت آب و هوایی سخت شده بود، اما خدا را شکر توانستیم برنده شویم و برد مهمی بود.  وی خاطرنشان کرد: بازی به بازی پیش می‌رویم و هدف‌مان فقط تک بازی است و به بازی بعدی نگاه نمی‌کنیم. تلاش می‌کنیم تک به تک بازی‌ها را ببریم و قهرمان شویم. بازیکن تیم فوتبال پرسپولیس درمورد اینکه گفته می‌شود کار این تیم برای قهرمانی در لیگ برتر سخت است، عنوان کرد: فاصله زیادی بین تیم‌ها نیست که بگوییم سخت شده است. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  2659 with score:  0.03869404840956041
# title:  آبشک: بیرون زمین با هم رفیق هستیم، اما در زمین برای موفقیت تیم می‌جنگیم
# content:
# به گزارش خبرنگار ورزشی خبرگزاری فارس، محمد آبشک پس از کسب عنوان قهرمانی سوپرجام فوتبال ایران اظهار داشت: در چند سال اخیر همیشه مقابل پرسپولیس خوب بازی می‌کردیم، اما در کسب نتیجه موفق نبودیم. این بازی تک مسابقه بود و حساسیت‌ها بالا رفته بود و خدا را شکر که برنده شدیم. وی درمورد برخوردهایی که در این بازی وجود داشت، گفت: فوتبال همین است. همانطور که آنها حرف می‌زنند ما هم صحبت می‌کنیم. در فوتبال برخورد هم وجود دارد. بیرون از زمین با هم رفیق هستیم، اما در زمین برای موفقیت تیم می‌جنگیم. بازیکن تیم فوتبال فولاد درخصوص تذکر نکونام به او، گفت: نکونام تذکر داد که با داور صحبت نکنم که اخطار دوم را نگیرم. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  1470 with score:  0.0386594647278324
# title:  مصلح: نیاز داشتیم مقابل پرسپولیس هجومی‌تر بازی کنیم
# content:
# به گزارش خبرگزاری فارس از کرمان، شایان مصلح پس از تساوی گل گهر مقابل پرسپولیس اظهار داشت: بازی جانداری بود. هر دو تیم موقعیت‌های خوبی داشتند. می توانستیم از موقعیت هایمان بهتر استفاده کنیم. ولی به هرحال این نتیجه رقم خورد و ان شاالله در بازی‌های بعدی بهتر نتیجه بگیریم. وی در خصوص خروجش از زمین در نیمه اول، عنوان کرد: بازی قبلی برای تیم گل زدم. در این بازی هم تعویض تاکتیکی انجام شد. تیم گل خورده بود و نیاز داشتیم هجومی تر بازی کنیم. احترام می گذارم. فرق بازیکن حرفه‌ای با بازیکن غیرحرفه‌ای همین است. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  1083 with score:  0.03445758408932446
# title:  عنایتی: تساوی ما مقابل فولاد عادلانه بود/توقعم از بازیکنان هوادار خیلی بالاتر بود
# content:
# به گزارش خبرنگار ورزشی خبرگزاری فارس، رضا عنایتی سرمربی تیم هوادار تهران پس از تساوی بدون گل تیمش مقابل فولاد خوزستان در نشست خبری بعد از بازی گفت: فکر می‌کنم بازی خوبی بود، بازی جان‌داری بود هم ما می‌توانستیم برنده بازی باشیم هم تیم حریف. به باشگاه فولاد هم خسته‌نباشید می‌گویم و از نتیجه بازی راضی نیستم هر چند بچه‌های ما در تمام بازی‌ها تمام تلاش‌شان را می‌کنند ولی از این شرایط راضی نیستم. ما با 4، 5 بازیکن مصدوم‌مان به این بازی آمدیم. نتیجه مساوی برای این بازی عادلانه بود. وی در ادامه افزود:‌ توقع من از بازیکنانم خیلی بالاتر بود ولی متأسفانه مصدوم‌هایی که ما داشتیم شرایط تیم را تغییر داده بود. نحوه بازی هم به شکلی شد که توپ روی هوا بود و تمام بازی تیم مقابل بازی بلند و توپ‌های سوم بود که این کیفیت کار را پایین آورده بود و مساوی تعیین نتیجه بود. به هر دو تیم خسته نباشید می‌گویم. وی در پاسخ به این سوال که تنش بین نیمکت دو تیم خیلی در حین بازی زیاد بود اظهار داشت: ما با جواد نکونام اصلا بحث و تنش نداریم ما خیلی خیلی با هم دوست هستیم. جواد از دوستان بسیار خوب من است و اگر در بعضی از صحنه‌ها صحبت کردیم صحبت دوستانه بود و بحث جار و جنجال نبود ولی فکر می‌کنم بین دو نیمکت تنش وجود داشت و این هم به گفته خودشان به دلیل تصمیمات داور بود. من اصلا به این موضوع ورود نکردم و فقط سعی کردم نیمکت را آرام کنم و چیز خاصی نبود. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  1550 with score:  0.034345747343764735
# title:  واکنش آلگری به تساوی یووه مقابل زیردریایی های زرد
# content:
# به گزارش خبرگزاری فارس، تیم فوتب
انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  6464 with score:  0.03253058333526157
# title:  اعتراض رسمی تراکتور به داوری بازی تراکتور و مس رفسنجان
# content:
# به گزارش خبرگزاری فارس و به نقل از رسانه باشگاه تراکتور، باتوجه به اشتباهات تاثیرگذار داوری بازی دو تیم تراکتور و مس رفسنجان در جام حذفی، باشگاه تراکتور نامه اعتراضی خود نسبت به این موضوع را به همراه مستنداتش به فدراسیون فوتبال و سازمان لیگ ارسال کرد. همچنین در این نامه رسمی، نسبت به تغییر شائبه برانگیز کمک داور دوم در روز بازی، اعتراض شده است.  باشگاه تراکتور نامه شکایت و اعتراض به قضاوت داور را براساس قانون در کمتر از پنج ساعت بعد از پایان بازی، به فدراسیون فوتبال ارسال کرد. انتهای پیام/
#
#
#
# --------------------------------------
# jacquard:
#
# found doc:  4422 with score:  0.0851063829787234
# title:  تست کرونای بازیکنان و کادر فنی استقلال مثبت شد/ غیبت مجیدی در نشست خبری بازی با پیکان
# content:
# به گزارش خبرنگار ورزشی خبرگزاری فارس، با اعلام محمد نوری‌فر، مدیر رسانه‌ای باشگاه استقلال نتیجه تست کرونای تعداد زیادی از بازیکنان و اعضای کادر تیم فوتبال استقلال مثبت اعلام شده است. نشست خبری فرهاد مجیدی در پیش از بازی با پیکان به دلیل شرایط ویژه رخ داده، برگزار نخواهد شد. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  157 with score:  0.07272727272727272
# title:  لالیگای 2| تساوی پونفرادنیا با کلین شیت عابدزاده
# content:
# به گزارش خبرگزاری فارس، تیم فوتبال پونفرادینا شب گذشته در هفته سی و یکم رقابت های لالیگای 2 به مصاف مالاگا رفت و به نتیجه تساوی بدون گل رضایت داد. امیر عابدزاده دروازه بان ملی پوش کشورمان در این بازی 90 دقیقه برای پونفرادینا بازی کرد و موفق به کلین شیت شد. پونفرادنیا با این تساوی 50 امتیازی شد و در رده پنجم ایستاد. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  250 with score:  0.07272727272727272
# title:  لیگ ستارگان قطر| شکست الوکره در شب غیبت ابراهیمی
# content:
# به گزارش خبرگزاری فارس،  در چارچوب هفته بیست و دوم لیگ ستارگان قطر، تیم فوتبال الوکره به مصاف السد رفت و با نتیجه 2 بر یک شکست خورد.  در این بازی امید ابراهیمی در لیست بازیکنان الوکره حضور نداشت.  السد با این برد 62 امتیازی شد تا با اقتدار در صدر قرار گیرد. الوکره نیز با 37 امتیاز در رده سوم جای دارد.  انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  5914 with score:  0.07272727272727272
# title:  هفته بیستم لیگ انگلیس|  لک لک‌ها قربانی روباه شدند
# content:
# به گزارش خبرگزاری فارس، تیم فوتبال لیورپول در هفته بیستم لیگ برتر انگلیس میهمان لسترسیتی بود که با نتیجه یک بر صفر شکست خورد. گل پیروزی بخش شاگردان راجرز را در این بازی لوکمن در دقیقه 59 به ثمر رساند. لک لک ها با این باخت با 41 امتیاز در رده دوم ماندند. منچستر سیتی با 47 امتیاز صدرنشین لیگ جزیره است. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  1189 with score:  0.07142857142857142
# title:  سوپر لیگ ترکیه| پیروزی آلتای اسپور قعرنشین با نادری
# content:
# به گزارش خبرگزاری فارس، تیم فوتبال آلتای اسپور امروز در هفته بیست و هفتم سوپر لیگ ترکیه به مصاف تیم گازی انتپ رفت و با نتیجه 3 بر 2 به پیروزی رسید. محمد نادری مدافع سابق استقلال در این بازی از ابتدا در ترکیب آلتای اسپور حضور داشت و 90 دقیقه برای تیمش بازی کرد. آلتای اسپور با این برد 25 امتیازی شد و در رده هجدهم ماند. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  4550 with score:  0.07017543859649122
# title:  هفته نوزدهم لیگ هلند| باخت فاینورد در حضور کاپیتان تیم ملی ایران
# content:
# به گزارش خبرگزاری فارس، تیم فوتبال فاینورد شب گذشته در هفته نوزدهم لیگ برتر هلند به مصاف تیم ویسته آرنهایم رفت که با نتیجه یک بر صفر شکست خورد. علیرضا جهانبخش هافبک ملی پوش کشورمان در این بازی از ابتدا در ترکیب بود و 90 دقیقه بازی کرد ولی نتوانست مانع شکست تیمش بود. فاینورد با این شکست با 39 امتیاز در رده سوم جدول ماند. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  1779 with score:  0.06896551724137931
# title:  هفته بیست و پنجم لالیگا| تحکیم صدرنشینی رئال با برد آلاوس
# content:
# به گزارش خبرگزاری فارس، تیم فوتبال رئال مادرید شب گذشته در هفته بیست و پنجم لالیگا میزبان آلاوس بود که با نتیجه 3 بر صفر به پیروزی رسید. گل های شاگردان آنچلوتی در این بازی را به ترتیب آسنسیو(63)، جونیور(80) و بنزما(1+90) به ثمر رساندند. رئال با این برد 57 امتیازی شد و صدرنشینی خود را تحکیم بخشید. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  5166 with score:  0.06818181818181818
# title:  دانشگر از بازی بعدی استقلال محروم شد
# content:
# به گزارش خبرنگار ورزشی خبرگزاری فارس، محمد دانشگر مدافع تیم فوتبال استقلال امروز مقابل مس رفسنجان کارت زرد دریافت کرد و از بازی بعدش تیمش محروم شد. استقلال در هفته پانزدهم پنجشنبه 23 دی ماه به مصاف نفت مسجد سلیمان خواهد رفت. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  3107 with score:  0.06779661016949153
# title:  واکنش AFC به پیروزی تیم ملی مقابل شاگردان مارویک/اماراتی ها با گل طارمی دبل شدند
# content:
# به گزارش خبرگزاری فارس، تیم ملی فوتبال کشورمان در مصاف با امارات با نتیجه یک بر صفر به پیروزی رسید. تک گل این بازی را مهدی طارمی در اواخر نیمه اول به ثمر رساند. صفحه رسمی کنفدراسیون فوتبال آسیا به پیروزی تیم ملی کشورمان واکنش نشان داد و نوشت: گل مهدی طارمی در نیمه اول برای دبل شدن امارات مقابل ایران کافی بود. اماراتی ها در دیدار رفت هم در کشورشان مقابل تیم ملی فوتبال کشورمان شکست خورده بودند. انتهای پیام/
#
#
#
# --------------------------------------
# found doc:  1144 with score:  0.06779661016949153
# title:  هفته بیست و چهارم لیگ پرتغال| طارمی پاس گل داد، پورتو متوقف شد
# content:
# به گزارش خبرگزاری فارس، تیم فوتبال پورتو بامداد امروز(دوشنبه) در هفته بیست و چهارم لیگ برتر پرتغال به مصاف ژیل ویسنته رفت و با نتیجه تساوی یک بر یک متوقف شد. مهدی طارمی ستاره ایرانی پورتو از ابتدا در ترکیب تیمش حضور داشت و 90 دقیقه بازی کرد. مهاجم ایرانی در در دقیقه 66 گل تساوی تیمش را ساخت. پورتو با این تساوی با 64 امتیاز صدرنشین لیگ پرتغال ماند. انتهای پیام/
#
#
#
# --------------------------------------
# jacquard with champions list:
#
# found doc:  4422 with score:  0.0851063829787234
# title:  تست کرونای بازیکنان و کادر فنی استقلال مثبت شد/ غیبت مجیدی در نشست خبری بازی با پیکان
# content:
# به گزارش خبرنگار ورزشی خبرگزاری فارس، با اعلام محمد نوری‌فر، مدیر رسانه‌ای باشگاه استقلال نتیجه تست کرونای تعداد زیادی از بازیکنان و اعضای کادر تیم فوتبال استقلال مثبت اعلام شده است. نشست خبری فرهاد مجیدی در پیش از بازی با پیکان به دلیل شرایط ویژه رخ داده، برگزار نخواهد شد. انتهای پیام/
#
#
#
# found doc:  3107 with score:  0.06779661016949153
# title:  واکنش AFC به پیروزی تیم ملی مقابل شاگردان مارویک/اماراتی ها با گل طارمی دبل شدند
# content:
# به گزارش خبرگزاری فارس، تیم ملی فوتبال کشورمان در مصاف با امارات با نتیجه یک بر صفر به پیروزی رسید. تک گل این بازی را مهدی طارمی در اواخر نیمه اول به ثمر رساند. صفحه رسمی کنفدراسیون فوتبال آسیا به پیروزی تیم ملی کشورمان واکنش نشان داد و نوشت: گل مهدی طارمی در نیمه اول برای دبل شدن امارات مقابل ایران کافی بود. اماراتی ها در دیدار رفت هم در کشورشان مقابل تیم ملی فوتبال کشورمان شکست خورده بودند. انتهای پیام/
#
#
#
# found doc:  3043 with score:  0.06666666666666667
# title:  علیاری به فجر سپاسی پیوست
# content:
# به گزارش خبرگزاری فارس، رضا علیاری مدافع اسبق تیم فوتبال سایپا به تیم فوتبال فجر شهید سپاسی پیوست. علیاری سابقه بازی در راه آهن،نفت تهران ،گل گهر سیرجان و نساجی مازندران را در کارنامه دارد. فجر شهید سپاسی در حال تقویت تیمش برای نیم فصل دوم است. انتهای پیام/
#
#
#
# found doc:  158 with score:  0.06557377049180328
# title:  هفته بیست و نهم سری‌آ| میلان با برد صدرنشینی اش را تحکیم بخشید
# content:
# به گزارش خبرگزاری فارس، تیم فوتبال میلان شب گذشته در هفته بیست و نهم سری آ به مصاف امپولی رفت و با نتیجه یک بر صفر به پیروزی رسید. گل پیروزی بخش روسونری در این بازی را کالولو در دقیقه 19 به ثمر رساند. میلان با این برد 63 امتیازی شد و صدرنشینی خود را تحکیم بخشید. در دیگر بازی از هفته بیست و هشتم لالیگا والنسیا میهمان ختافه بود که این بازی با نتیجه تساوی بدون گل به پایان رسید. انتهای پیام/
#
#
#
# found doc:  3925 with score:  0.06349206349206349
# title:  مدت تعطیلی تمرینات پرسپولیس مشخص شد
# content:
# به گزارش خبرنگار ورزشی خبرگزاری فارس، تیم فوتبال پرسپولیس امشب در هفته شانزدهم لیگ برتر با نتیجه یک بر صفر فولاد خوزستان را شکست داد. پس از این اتفاق، با نظر یحیی گل‌محمدی، تمرینات سرخ‌پوشان سه روز تعطیل شد. آنها از ۶ بهمن کار خود را برای دیدار سوپرجام و ادامه لیگ برتر آغاز خواهند کرد. پرسپولیس ۱۸ بهمن در بازی سوپرجام به میزبانی سیرجان، بار دیگر به مصاف فولاد می‌رود. انتهای پیام /
#
#
#
# found doc:  6712 with score:  0.0625
# title:  لیگ‌های اروپا| قدرت نمایی بایرن و اینتر مقابل رقبا
# content:
# به گزارش خبرگزاری فارس، تیم فوتبال بایرن مونیخ در اولین بازی از هفته هفدهم بوندسلیگا به مصاف وولفسبورگ رفت و با نتیجه پرگل 4 بر صفر به پیروزی رسید. باوارایی ها با این برد ارزشمند 43 امتیازی شد و فاصله خود را با تیمی دومی در صدر زیاد کردند. در دیگر بازی از هفته هجدهم سری آ ایتالیا اینتر میهمان سالرنینتا بود که با نتیجه پرگل 5 بر صفر به پیروزی رسید. شاگردان اینزاگی با این برد 43 امتیازی شدند و صدرنشینی خود را تحکیم بخشیدند. انتهای پیام/
#
#
#
# found doc:  1141 with score:  0.06153846153846154
# title:  آتش بازی بارسلونا مقابل بیلبائو/ناپولی با شکار عقاب صدرنشین شد
# content:
# به گزارش خبرگزاری فارس، تیم فوتبال بارسلونا شب گذشته در هفته بیست و ششم لالیگا به مصاف بیلبائو رفت و با نتیجه پرگل 4 بر صفر به پیروزی رسید. بارسلونا با این برد ارزشمند 45 امتیازی شد و رده چهارمی را از اتلتیکو پس گرفت. در دیگر بازی در هفته بیست و هفتم سری آ لاتزیو میزبان ناپولی بود که در نهایت در ثانیه های پایانی با نتیجه 2 بر یک تن به شکست داد. ناپولی با این برد 58 امتیازی شد و صدر را از میلان گرفت. انتهای پیام/
#
#
#
# found doc:  6548 with score:  0.061224489795918366
# title:  لیگ فوتبال بلژیک| برد پرگل شارلروا در شب گلزنی قلی زاده
# content:
# به گزارش خبرگزاری فارس، از هفته بیستم رقابت های لیگ فوتبال بلژیک، شارلروا میهمان یوپن بود و با نتیجه 4 بر صفر به برتری دست یافت. در این بازی علی قلی زاده گل اول بازی را به ثمر رساند. شارلروا با این پیروزی 32 امتیازی شد و در رده ششم قرار دارد. انتهای پیام/
#
#
#
# found doc:  115 with score:  0.058823529411764705
# title:  لیگ فوتبال هلند|پیروزی فاینورد در خانه زووله بدون جهانبخش
# content:
# به گزارش خبرگزاری فارس، از هفته بیست و ششم رقابت های لیگ فوتبال هلند، فاینورد میهمان زووله بود و با نتیجه دو بر یک به پیروزی رسید. در این بازی علیرضا جهانبخش بازیکن ایرانی در ترکیب اصلی تیمش حضور نداشت و نیمکت نشین بود. فاینورد با این پیروزی 55 امتیازی شد و در رده سوم قرار دارد. انتهای پیام/
#
#
#
# found doc:  3511 with score:  0.058823529411764705
# title:  واکنش جالب فیفا به صعود تیم ملی به جام جهانی/حضور ایران در 3 دوره متوالی در بزرگترین تورنمنت فوتبال +عکس
# content:
# به گزارش خبرگزاری فارس، تیم ملی فوتبال کشورمان موفق شد در دیدار مقابل عراق به پیروزی یک بر صفر دست یابد و جواز حضور در جام جهانی 2022 قطر را بدست آورد. تک گل این بازی را مهدی طارمی به ثمر رساند. فیفا بابت صعود تیم ملی به جام جهانی پوستر جالبی را منتشر کرد.    انتهای پیام/
